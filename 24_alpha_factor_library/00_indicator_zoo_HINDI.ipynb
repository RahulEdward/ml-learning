# %% [markdown]
# # The Indicator Zoo

# %% [markdown]
# Source:
#
# Green, Jeremiah aur Hand, John R. M. and Zhang, Frank, [The Characteristics that Provide Independent Information ke baare mein Average U.S. Monthly Stock Returns](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2262374), The Review ka Financial Studies, Volume 30, Issue 12, December 2017, Pages 4389–4436

# %% [markdown]
# In his 2011 American Finance Association Presidential address, John H. Cochrane (2011) challenged researchers to identify firm characteristics that provide independent information ke baare mein average U.S. stock returns.
#
# Cochrane issued his challenge because ka the “veritable zoo” of hundreds ka characteristics that have been presented as statistically significant predictors ka cross-section ka returns mein anomalies literature since 1970.

# %% [markdown]
# | Acronym    | Author(s)                           | Date, Journal | Definition ka characteristic-based anomaly variable                                                                                                                                                                                                                                 |
# |------------|-------------------------------------|---------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | acc        | Sloan                               | 1996, TAR     | Annual income before extraordinary items (ib) minus operating cash flows (oancf) divided by average total assets (at); if oancf hai missing toh set to change mein act - change mein che - change mein lct++ change mein dlc++ change mein txp-dp                                                 |
# | aeavol     | Lerman, Livnat, and Mendenhall      | 2008, WP      | Average daily trading volume (vol) for 3 days around earnings announcement minus average daily volume ke liye 1-month ending 2 weeks before earnings announcement divided by 1-month average daily volume. Earnings announcement day se Compustat quarterly (rdq)                         |
# | age        | Jiang, Lee, and Zhang               | 2005, RAS     | Number ka years since first Compustat coverage                                                                                                                                                                                                                                          |
# | agr        | Cooper, Gulen, and Schill           | 2008, JF      | Annual percent change mein total assets (at)                                                                                                                                                                                                                                              |
# | baspread   | Amihud aur Mendelson                | 1989, JF      | Monthly average ka daily bid-ask spread divided by average ka daily spread                                                                                                                                                                                                              |
# | beta       | Fama aur MacBeth                    | 1973, JPE     | Estimated market beta se weekly returns aur equal weighted market returns ke liye 3 years ending month tt-1 ke saath at least 52 weeks ka returns                                                                                                                                             |
# | bm         | Rosenberg, Reid, and Lanstein       | 1985, JPM     | Book value ka equity (ceq) divided by end ka fiscal year-end market capitalization                                                                                                                                                                                                      |
# | bm_ia      | Asness, Porter, and Stevens         | 2000, WP      | Industry adjusted book-to-market ratio                                                                                                                                                                                                                                                  |
# | cash       | Palazzo                             | 2012, JFE     | Cash aur cash equivalents divided by average total assets                                                                                                                                                                                                                               |
# | cashdebt   | Ou aur Penman                       | 1989, JAE     | Earnings before depreciation aur extraordinary items (ib++dp) divided by avg. total liabilities (lt)                                                                                                                                                                                    |
# | cashpr     | Chandrashekar aur Rao               | 2009, WP      | Fiscal year-end market capitalization plus long-term debt (dltt) minus total assets (at) divided by cash aur equivalents (che)                                                                                                                                                          |
# | cfp        | Desai, Rajgopal, and Venkatachalam  | 2004, TAR     | Operating cash flows divided by fiscal-year-end market capitalization                                                                                                                                                                                                                   |
# | cfp_ia     | Asness, Porter aur Stevens          | 2000, WP      | Industry adjusted cfp                                                                                                                                                                                                                                                                   |
# | chatoia    | Soliman                             | 2008, TAR     | 2-digit SIC - fiscal-year mean-adjusted change mein sales (sale) divided by average total assets (at)                                                                                                                                                                                     |
# | chcsho     | Pontiff aur Woodgate                | 2008, JF      | Annual percent change mein shares outstanding (csho)                                                                                                                                                                                                                                      |
# | chempia    | Asness, Porter, and Stevens         | 1994, WP      | Industry-adjusted change mein number ka employees                                                                                                                                                                                                                                         |
# | chfeps     | Hawkins, Chamberlin, and Daniel     | 1984, FAJ     | Mean analyst forecast mein month prior to fiscal period end date se I/B/E/S summary file minus same mean forecast ke liye prior fiscal period using annual earnings forecasts                                                                                                               |
# | chinv      | Thomas aur Zhang                    | 2002, RAS     | Change mein inventory (inv) scaled by average total assets (at)                                                                                                                                                                                                                           |
# | chmom      | Gettleman aur Marks                 | 2006, WP      | Cumulative returns se months tt-6 to tt-1 minus months tt-12 to tt-7                                                                                                                                                                                                                  |
# | chpmia     | Soliman                             | 2008, TAR     | 2-digit SIC - fiscal-year mean adjusted change mein income before extraordinary items (ib) divided by sales (sale)                                                                                                                                                                        |
# | chtx       | Thomas aur Zhang                    | 2011, JAR     | Percent change mein total taxes (txtq) from quartertt-4 to tt                                                                                                                                                                                                                             |
# | cinvest    | Titman, Wei, and Xie                | 2004, JFQA    | Change over one quarter mein net PP&E (ppentq) divided by sales (saleq) - average ka this variable ke liye prior 3 quarters; if saleq== 0, then scale by 0.01                                                                                                                                 |
# | convind    | Valta                               | 2016, JFQA    | An indicator equal to 1 agar company has convertible debt obligations                                                                                                                                                                                                                     |
# | currat     | Ou aur Penman                       | 1989, JAE     | Current assets / current liabilities                                                                                                                                                                                                                                                    |
# | depr       | Holthausen aur Larcker              | 1992, JAE     | Depreciation divided by PP&E                                                                                                                                                                                                                                                            |
# | disp       | Diether, Malloy, and Scherbina      | 2002, JF      | Standard deviation ka analyst forecasts mein month prior to fiscal period end date divided by absolute value ka mean forecast; if meanest== 0, then scalar set to 1. Forecast data se I/B/E/S summary files                                                                     |
# | divi       | Michaely, Thaler, and Womack        | 1995, JF      | An indicator variable equal to 1 agar company pays dividends lekin did not mein prior year                                                                                                                                                                                                    |
# | dolvol     | Chordia, Subrahmanyam, and Anshuman | 2001, JFE     | Natural log ka trading volume times price per share se month tt-2                                                                                                                                                                                                                     |
# | dy         | Litzenberger aur Ramaswamy          | 1982, JF      | Total dividends (dvt) divided by market capitalization at fiscal year-end                                                                                                                                                                                                               |
# | ear        | Kishore et al.                      | 2008, WP      | Sum ka daily returns mein three days around earnings announcement. Earnings announcement se Compustat quarterly file (rdq)                                                                                                                                                              |
# | egr        | Richardson et al.                   | 2005, JAE     | Annual percent change mein book value ka equity (ceq)                                                                                                                                                                                                                                     |
# | ep         | Basu                                | 1977, JF      | Annual income before extraordinary items (ib) divided by end ka fiscal year market cap                                                                                                                                                                                                  |
# | fgr5yr     | Bauman aur Dowen                    | 1988, FAJ     | Most recently available analyst forecasted 5-year growth                                                                                                                                                                                                                                |
# | gma        | Novy-Marx                           | 2013, JFE     | Revenues (revt) minus cost ka goods sold (cogs) divided by lagged total assets (at)                                                                                                                                                                                                     |
# | grCAPX     | Anderson aur Garcia-Feijoo          | 2006, JF      | Percent change mein capital expenditures se yeartt-2 to year tt                                                                                                                                                                                                                         |
# | grltnoa    | Fairfield, Whisenant, and Yohn      | 2003, TAR     | Growth mein long-term net operating assets                                                                                                                                                                                                                                                |
# | herf       | Hou aur Robinson                    | 2006, JF      | 2-digit SIC - fiscal-year sales concentration (sum ka squared percent ka sales mein industry ke liye each company).                                                                                                                                                                           |
# | hire       | Bazdresch, Belo, and Lin            | 2014, JPE     | Percent change mein number ka employees (emp)                                                                                                                                                                                                                                             |
# | idiovol    | Ali, Hwang, and Trombley            | 2003, JFE     | Standard deviation ka residuals ka weekly returns par weekly equal weighted market returns ke liye 3 years prior to month end                                                                                                                                                                |
# | ill        | Amihud                              | 2002, JFM     | Average ka daily (absolute return / dollar volume).                                                                                                                                                                                                                                     |
# | indmom     | Moskowitz aur Grinblatt             | 1999, JF      | Equal weighted average industry 12-month returns                                                                                                                                                                                                                                        |
# | invest     | Chen aur Zhang                      | 2010, JF      | Annual change mein gross property, plant, and equipment (ppegt) ++ annual change mein inventories (invt) all scaled by lagged total assets (at)                                                                                                                                             |
# | IPO        | Loughran aur Ritter                 | 1995, JF      | An indicator variable equal to 1 agar first year available par CRSP monthly stock file                                                                                                                                                                                                     |
# | lev        | Bhandari                            | 1988, JF      | Total liabilities (lt) divided by fiscal year-end market capitalization                                                                                                                                                                                                                 |
# | lgr        | Richardson et al.                   | 2005, JAE     | Annual percent change mein total liabilities (lt)                                                                                                                                                                                                                                         |
# | maxret     | Bali, Cakici, and Whitelaw          | 2011, JFE     | Maximum daily return se returns during calendar monthtt-1                                                                                                                                                                                                                             |
# | mom12m     | Jegadeesh                           | 1990, JF      | 11-month cumulative returns ending one month before month end                                                                                                                                                                                                                           |
# | mom1m      | Jegadeesh aur Titman                | 1993, JF      | 1-month cumulative return                                                                                                                                                                                                                                                               |
# | mom36m     | Jegadeesh aur Titman                | 1993, JF      | Cumulative returns se monthstt-36 to tt-13                                                                                                                                                                                                                                            |
# | ms         | Mohanram                            | 2005, RAS     | Sum ka 8 indicator variables ke liye fundamental performance                                                                                                                                                                                                                                |
# | mve        | Banz                                | 1981, JFE     | Natural log ka market capitalization at end ka month tt-1                                                                                                                                                                                                                               |
# | mve_ia     | Asness, Porter, and Stevens         | 2000, WP      | 2-digit SIC industry-adjusted fiscal year-end market capitalization                                                                                                                                                                                                                     |
# | nanalyst   | Elgers, Lo, and Pfeiffer            | 2001, TAR     | Number ka analyst forecasts se most recently available I/B/E/S summary files mein month prior to month ka portfolio formation. nanalyst set to zero agar not covered mein I/B/E/S summary file                                                                                              |
# | nincr      | Barth, Elliott, and Finn            | 1999, JAR     | Number ka consecutive quarters (up to eight quarters) with ek increase mein earnings (ibq) over same quarter mein prior year                                                                                                                                                            |
# | operprof   | Fama aur French                     | 2015, JFE     | Revenue minus cost ka goods sold - SG&A expense - interest expense divided by lagged common shareholders’ equity                                                                                                                                                                        |
# | orgcap     | Eisfeldt aur Papanikolaou           | 2013, JF      | Capitalized SG&A expenses                                                                                                                                                                                                                                                               |
# | pchcapx_ia | Abarbanell aur Bushee               | 1998, TAR     | 2-digit SIC - fiscal-year mean-adjusted percent change mein capital expenditures (capx)                                                                                                                                                                                                   |
# | pctacc     | Hafzalla, Lundholm, and Van Winkle  | 2011, TAR     | Same as acc except that numerator hai divided by absolute value ka ib; if ib== 0 toh ib set to 0.01 ke liye denominator                                                                                                                                                             |
# | pricedelay | Hou & Moskowitz                     | 2005, RFS     | The proportion ka variation mein weekly returns ke liye 36 months ending mein monthtt explained by 4 lags ka weekly market returns incremental to contemporaneous market return                                                                                                                 |
# | quick      | Ou aur Penman                       | 1989, JAE     | (current assets - inventory) / current liabilities                                                                                                                                                                                                                                      |
# | rd         | Eberhart, Maxwell, and Siddique     | 2004, JF      | An indicator variable equal to 1 agar R&D expense as ek percentage ka total assets has ek increase greater than 5%.                                                                                                                                                                        |
# | rd_mve     | Guo, Lev, and Shi                   | 2006, JBFA    | R&D expense divided by end-of-fiscal-year market capitalization                                                                                                                                                                                                                         |
# | realestate | Tuzel                               | 2010, RFS     | Buildings aur capitalized leases divided by gross PP&E                                                                                                                                                                                                                                  |
# | retvol     | Ang et al.                          | 2006, JF      | Standard deviation ka daily returns se month tt-1                                                                                                                                                                                                                                     |
# | roaq       | Balakrishnan, Bartov, and Faurel    | 2010, JAE     | Income before extraordinary items (ibq) divided by one quarter lagged total assets (atq)                                                                                                                                                                                                |
# | roavol     | Francis et al.                      | 2004, TAR     | Standard deviation ke liye 16 quarters ka income before extraordinary items (ibq) divided by average total assets (atq)                                                                                                                                                                     |
# | roeq       | Hou, Xue, and Zhang                 | 2015 RFS      | Earnings before extraordinary items divided by lagged common shareholders’ equity                                                                                                                                                                                                       |
# | roic       | Brown aur Rowe                      | 2007, WP      | Annual earnings before interest aur taxes (ebit) minus nonoperating income (nopi) divided by non-cash enterprise value (ceq++lt-che)                                                                                                                                                    |
# | rsup       | Kama                                | 2009, JBFA    | Sales se quarter t minus sales se quarter tt-4 (saleq) divided by fiscal-quarter-end market capitalization (cshoq * prccq)                                                                                                                                                          |
# | salecash   | Ou aur Penman                       | 1989, JAE     | Annual sales divided by cash aur cash equivalents                                                                                                                                                                                                                                       |
# | secured    | Valta                               | 2016, JFQA    | Total liability scaled secured debt                                                                                                                                                                                                                                                     |
# | sfe        | Elgers, Lo, and Pfeiffer            | 2001, TAR     | Analysts mean annual earnings forecast ke liye nearest upcoming fiscal year se most recent month available prior to month ka portfolio formation se I/B/E/S summary files scaled by price per share at fiscal quarter end                                                               |
# | sgr        | Lakonishok, Shleifer, and Vishny    | 1994, JF      | Annual percent change mein sales (sale)                                                                                                                                                                                                                                                   |
# | sin        | Hong & Kacperczyk                   | 2009, JFE     | An indicator variable equal to 1 agar ek company’s primary industry classification hai mein smoke ya tobacco, beer ya alcohol, or gaming                                                                                                                                                      |
# | SP         | Barbee, Mukherji, and Raines        | 1996, FAJ     | Annual revenue (sale) divided by fiscal year-end market capitalization                                                                                                                                                                                                                  |
# | std_dolvol | Chordia, Subrahmanyam, and Anshuman | 2001, JFE     | Monthly standard deviation ka daily dollar trading volume                                                                                                                                                                                                                               |
# | stdcf      | Huang                               | 2009, JEF     | Standard deviation ke liye 16 quarters ka cash flows divided by sales (saleq); if saleq== 0, then scale by 0.01. Cash flows defined as ibq minus quarterly accruals                                                                                                                         |
# | sue        | Rendelman, Jones, and Latane        | 1982, JFE     | Unexpected quarterly earnings divided by fiscal-quarter-end market cap. Unexpected earnings hai I/B/E/S actual earnings minus median forecasted earnings agar available, else it hai seasonally differenced quarterly earnings before extraordinary items se Compustat quarterly file |
# | tang       | Almeida aur Campello                | 2007, RFS     | Cash holdings ++ 0.715 ×× receivables ++0.547 ×× inventory ++ 0.535 ×× PPE/ totl assets                                                                                                                                                                                                 |
# | tb         | Lev aur Nissim                      | 2004, TAR     | Tax income, calculated se current tax expense divided by maximum federal tax rate, divided by income before extraordinary items                                                                                                                                                       |
# | turn       | Datar, Naik, and Radcliffe          | 1998, JFM     | Average monthly trading volume ke liye most recent 3 months scaled by number ka shares outstanding mein current month                                                                                                                                                                         |
# | zerotrade  | Liu                                 | 2006, JFE     | Turnover weighted number ka zero trading days ke liye most recent 1 month                                                                                                                                                                                                                   |
